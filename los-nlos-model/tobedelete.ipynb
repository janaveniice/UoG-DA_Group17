# %% [markdown]
# ## **This is used to test the saved models**

# %%
import joblib

filename = "logistic_regression_model.pkl"
loaded_model = joblib.load("final_models/" + filename)

# %%
print(type(loaded_model))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>

# %%
# Inspecting the coefficients and intercepts of the logistic regression model
print("Model Coefficients:", loaded_model.coef_)
print("Model Intercept:", loaded_model.intercept_)
print("Model Classes:", loaded_model.classes_)

# To view the full model attributes (it includes other properties and hyperparameters):
print("Full Model Attributes:")
print(vars(loaded_model))
# Out:
# Model Coefficients: [[-6.63308218e-02 -5.15887137e-03 -7.96437606e-04 -9.88220494e-05
#    6.55049932e-03  2.03207303e-04  9.13128277e-04  1.11764017e-02
#    6.50263370e-03 -1.19837109e-04]]
# Model Intercept: [0.0001016]
# Model Classes: [0. 1.]
# Full Model Attributes:
# {'penalty': 'l2', 'dual': False, 'tol': 0.0001, 'C': 1.0, 'fit_intercept': True, 'intercept_scaling': 1, 'class_weight': None, 'random_state': 42, 'solver': 'lbfgs', 'max_iter': 100, 'multi_class': 'deprecated', 'verbose': 0, 'warm_start': False, 'n_jobs': None, 'l1_ratio': None, 'feature_names_in_': array(['RANGE', 'FP_IDX', 'STDEV_NOISE', 'CIR_PWR', 'RXPACC', 'CH',
#        'PREAM_LEN', 'BITRATE', 'PRFR', 'FP_AMP_AVG'], dtype=object), 'n_features_in_': 10, 'classes_': array([0., 1.]), 'n_iter_': array([100], dtype=int32), 'coef_': array([[-6.63308218e-02, -5.15887137e-03, -7.96437606e-04,
#         -9.88220494e-05,  6.55049932e-03,  2.03207303e-04,
#          9.13128277e-04,  1.11764017e-02,  6.50263370e-03,
# ...
